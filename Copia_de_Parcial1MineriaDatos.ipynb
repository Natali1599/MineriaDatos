# %% [markdown]
# <a href="https://colab.research.google.com/github/Natali1599/MineriaDatos/blob/main/Copia_de_Parcial1MineriaDatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Parcial 1 Minería de datos

# %%
import pandas as pd
import numpy as np
import csv

# %%
pd.set_option('display.max_columns', None) #Mostrar todas las columnas

# %%
df = pd.read_csv(
    'https://raw.githubusercontent.com/prof-tatiana-gutierrez/DatosMD/master/student-mat.csv',
    sep = ";")
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother           2          2         0       yes     no   no
# 1  course   father           1          2         0        no    yes   no
# 2   other   mother           1          2         3       yes     no  yes
# 3    home   mother           1          3         0        no    yes  yes
# 4    home   father           1          2         0        no    yes  yes
#
#   activities nursery higher internet romantic  famrel  freetime  goout  Dalc  \
# ...

# %%
df.shape
# Out:
# (395, 33)

# %%
df.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
pd.unique(df['address'])
# Out:
# array(['U', 'R'], dtype=object)

# %% [markdown]
# ### 1. Valores vacios o nulos

# %%
df.isna()
# Out:
#      school    sex    age  address  famsize  Pstatus   Medu   Fedu   Mjob  \
# 0     False  False  False    False    False    False  False  False  False
# 1     False  False  False    False    False    False  False  False  False
# 2     False  False  False    False    False    False  False  False  False
# 3     False  False  False    False    False    False  False  False  False
# 4     False  False  False    False    False    False  False  False  False
# ..      ...    ...    ...      ...      ...      ...    ...    ...    ...
# 390   False  False  False    False    False    False  False  False  False
# 391   False  False  False    False    False    False  False  False  False
# 392   False  False  False    False    False    False  False  False  False
# 393   False  False  False    False    False    False  False  False  False
# 394   False  False  False    False    False    False  False  False  False
#
#       Fjob  reason  guardian  traveltime  studytime  failures  schoolsup  \
# ...

# %% [markdown]
# No tiene datos vacios o nulos.

# %% [markdown]
# ### 2. ¿cuántos estudiantes viven en zona urbana o rural? ¿cuántos de los estudiante rurales son mujeres?

# %%
df["address"].value_counts()
# Out:
# U    307
# R     88
# Name: address, dtype: int64

# %% [markdown]
# En la zona urbana viven 307 y en la zona rural viven 88

# %%
df["sex"].value_counts()
# Out:
# F    208
# M    187
# Name: sex, dtype: int64

# %%
tab1 = pd.crosstab(df["address"],df["sex"])
tab1
# Out:
# sex        F    M
# address
# R         44   44
# U        164  143

# %% [markdown]
# Mujeres estudiantes rurales son 44.

# %% [markdown]
# ### 3. ¿cuántos estudiantes que viven en la zona rural tiene menos de 5 fallas? ¿Cuántos de ellos son mujeres?

# %%
df["absences"].value_counts()
# Out:
# 0     115
# 2      65
# 4      53
# 6      31
# 8      22
# 10     17
# 14     12
# 12     12
# 3       8
# 16      7
# 7       7
# 5       5
# 18      5
# 20      4
# 11      3
# 9       3
# 13      3
# 15      3
# 22      3
# 1       3
# 38      1
# 30      1
# 40      1
# 23      1
# 19      1
# 28      1
# 75      1
# 21      1
# 24      1
# 56      1
# 26      1
# 54      1
# 25      1
# 17      1
# Name: absences, dtype: int64

# %%
dfrural = df[df['address']=="R"]
dfrural
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 24      GP   F   15       R     GT3       T     2     4  services   health
# 32      GP   M   15       R     GT3       T     4     3   teacher  at_home
# 37      GP   M   16       R     GT3       A     4     4     other  teacher
# 38      GP   F   15       R     GT3       T     3     4  services   health
# 39      GP   F   15       R     GT3       T     2     2   at_home    other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...      ...
# 385     MS   F   18       R     GT3       T     2     2   at_home    other
# 386     MS   F   18       R     GT3       T     4     4   teacher  at_home
# 387     MS   F   19       R     GT3       T     2     3  services    other
# 392     MS   M   21       R     GT3       T     1     1     other    other
# 393     MS   M   18       R     LE3       T     3     2  services    other
#
# ...

# %%
tab4=dfrural[dfrural['absences'] < 5]
tab4
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 24      GP   F   15       R     GT3       T     2     4  services    health
# 32      GP   M   15       R     GT3       T     4     3   teacher   at_home
# 38      GP   F   15       R     GT3       T     3     4  services    health
# 68      GP   F   15       R     LE3       T     2     2    health  services
# 72      GP   F   15       R     GT3       T     1     1     other     other
# 95      GP   F   15       R     GT3       T     1     1   at_home     other
# 96      GP   M   16       R     GT3       T     4     3  services     other
# 111     GP   F   16       R     GT3       T     3     3  services     other
# 128     GP   M   18       R     GT3       T     2     2  services     other
# 130     GP   F   15       R     GT3       T     3     4  services   teacher
# 134     GP   M   15       R     GT3       T     3     4   at_home   teacher
# ...

# %%
tab4.shape
# Out:
# (49, 33)

# %% [markdown]
# La cantidad de estudiantes que viven en la zona rural y tienen menos de 5 fallas son 49.

# %%
tab5=tab4[tab4['sex']=="M"] 
tab5
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 32      GP   M   15       R     GT3       T     4     3   teacher   at_home
# 96      GP   M   16       R     GT3       T     4     3  services     other
# 128     GP   M   18       R     GT3       T     2     2  services     other
# 134     GP   M   15       R     GT3       T     3     4   at_home   teacher
# 136     GP   M   17       R     GT3       T     3     4   at_home     other
# 155     GP   M   15       R     GT3       T     2     3   at_home  services
# 158     GP   M   16       R     GT3       T     2     2   at_home     other
# 160     GP   M   17       R     LE3       T     2     1   at_home     other
# 164     GP   M   17       R     LE3       T     1     1     other  services
# 189     GP   M   17       R     GT3       T     1     2   at_home     other
# 231     GP   M   17       R     GT3       T     2     2     other     other
# ...

# %%
tab5.shape
# Out:
# (25, 33)

# %% [markdown]
# La cantidad de mujeres de la zona rural que tienen menos de 5 ausencias son 25.

# %% [markdown]
# ### 4. Ver la media de las notas de matemáticas de primer corte (G1) de los estudiantes deel colegio gabriel pereira vs Mousinho da Silveita, teniendo en cuenta si los estudiantes tienen o no internet en sus casas.

# %%
colgp = df[df['school']=="GP"]
colgp
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1  at_home     other
# 2       GP   F   15       U     LE3       T     1     1  at_home     other
# 3       GP   F   15       U     GT3       T     4     2   health  services
# 4       GP   F   16       U     GT3       T     3     3    other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...      ...       ...
# 344     GP   F   18       U     GT3       T     2     3  at_home     other
# 345     GP   F   18       U     GT3       T     3     2    other  services
# 346     GP   M   18       R     GT3       T     4     3  teacher  services
# 347     GP   M   18       U     GT3       T     4     3  teacher     other
# 348     GP   F   17       U     GT3       T     4     3   health     other
#
# ...

# %%
colgp.shape
# Out:
# (349, 33)

# %%
colms = df[df['school']=="MS"]
colms
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 349     MS   M   18       R     GT3       T     3     2     other     other
# 350     MS   M   19       R     GT3       T     1     1     other  services
# 351     MS   M   17       U     GT3       T     3     3    health     other
# 352     MS   M   18       U     LE3       T     1     3   at_home  services
# 353     MS   M   19       R     GT3       T     1     1     other     other
# 354     MS   M   17       R     GT3       T     4     3  services     other
# 355     MS   F   18       U     GT3       T     3     3  services  services
# 356     MS   F   17       R     GT3       T     4     4   teacher  services
# 357     MS   F   17       U     LE3       A     3     2  services     other
# 358     MS   M   18       U     LE3       T     1     1     other  services
# 359     MS   F   18       U     LE3       T     1     1   at_home  services
# ...

# %%
colms.shape
# Out:
# (46, 33)

# %%
#internet
#G1
tabgg=pd.pivot_table(colms, index=['G1','internet'], aggfunc=np.mean)
tabgg
# Out:
#                  Dalc      Fedu         G2         G3      Medu      Walc  \
# G1 internet
# 6  no        2.000000  1.333333   5.000000   1.666667  2.000000  2.333333
#    yes       1.500000  3.000000   5.000000   5.500000  2.500000  2.500000
# 7  no        1.000000  2.000000   7.000000   9.000000  3.000000  1.000000
#    yes       1.000000  1.500000   6.500000   3.750000  2.000000  2.000000
# 8  yes       2.500000  1.833333   8.000000   8.833333  1.500000  3.000000
# 9  no        4.000000  2.000000   9.000000   9.000000  2.000000  5.000000
# 10 no        1.750000  2.250000   9.000000   9.000000  1.750000  2.750000
#    yes       1.500000  1.000000  10.000000  10.000000  2.000000  2.500000
# 11 yes       2.200000  2.600000  11.400000  10.600000  2.600000  3.000000
# 12 no        1.000000  2.000000  11.500000  11.500000  2.000000  2.000000
#    yes       1.000000  4.000000  13.000000  13.000000  4.000000  2.000000
# ...

# %%
pd.pivot_table(colgp, index=['G1','internet'], aggfunc=np.mean)
# Out:
#                  Dalc      Fedu         G2         G3      Medu      Walc  \
# G1 internet
# 3  yes       1.000000  3.000000   5.000000   5.000000  3.000000  3.000000
# 4  yes       1.000000  3.000000   0.000000   0.000000  3.000000  1.000000
# 5  no        1.000000  2.500000   7.000000   6.500000  2.500000  3.000000
#    yes       1.000000  2.000000   3.800000   3.600000  2.400000  2.000000
# 6  no        1.000000  2.666667   6.666667   5.333333  2.666667  1.333333
#    yes       1.750000  2.062500   5.812500   4.312500  2.625000  3.312500
# 7  no        1.500000  1.750000   5.250000   5.750000  1.500000  3.000000
#    yes       1.535714  2.357143   7.178571   5.714286  2.714286  2.035714
# 8  no        1.222222  2.555556   8.555556   8.555556  2.444444  2.555556
#    yes       1.269231  2.038462   8.307692   7.807692  2.346154  2.076923
# 9  no        1.200000  1.800000   7.000000   6.000000  1.400000  3.000000
# ...

# %% [markdown]
# ### 5. Cree una variable en la tabla que corresponda a la calificación total para cada uno de los estudiantes teniendo en cuenta lo siguiente:
#
#
# *   G1 (35%)
# *   G2 (35%)
# *   G3 (30%)

# %%
from scipy import stats
import numpy as np

# %%
# !pip install dfply
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 612 kB 32.5 MB/s
# ...

# %%
from sklearn import datasets
from dfply import *
import numpy as np

# %%
Base10 = (df >>
 mutate(
   total = (X.G1*0.35+X.G2*0.35+X.G3*0.30),
 ))
Base10.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0  course   mother           2          2         0       yes     no   no
# 1  course   father           1          2         0        no    yes   no
# 2   other   mother           1          2         3       yes     no  yes
# 3    home   mother           1          3         0        no    yes  yes
# 4    home   father           1          2         0        no    yes  yes
#
#   activities nursery higher internet romantic  famrel  freetime  goout  Dalc  \
# ...

# %%
Base10.shape
# Out:
# (395, 34)

# %%
Base10['total'].describe()
# Out:
# count    395.000000
# mean      10.692532
# std        3.662308
# min        1.400000
# 25%        8.350000
# 50%       10.700000
# 75%       13.325000
# max       19.300000
# Name: total, dtype: float64

# %% [markdown]
# *   La media es 10.69
# *   La mediana es 3.66
# *   Mínima calificación es 1.4
# *   La máxima calificación es 19.30

# %% [markdown]
# ### 6. Responda

# %% [markdown]
# * ¿Qué tipo de análisis realizaría ¿Regresión o clasificación??
# Respuesta: Clasificación, por tener mayor cantidad de variables discretas.
# * ¿Que variable usaría para predecir o clasificar?
# Respuesta: La nota total / notas
# * ¿cuáles variables tiene la hipótesis que podrían servir para pronosticar o clasificar?
# Respuesta: La nota total, nota por cortes, sexo, edad, zona, tiempo de estudio, reprobaciones, schoolsup, internet, ausencias.

# %% [markdown]
# ### Bibliografía
# https://archive.ics.uci.edu/ml/datasets/student+performance
